# %%
import pandas as pd
traindf=pd.read_csv("train.csv")
test=pd.read_csv("test.csv")

# %%
traindf
# Out:
#        row_id  user_id  category_id  video_id  age  gender  \
# 0           1    19990           37       128   24    Male
# 1           2     5304           32       132   14  Female
# 2           3     1840           12        24   19    Male
# 3           4    12597           23       112   19    Male
# 4           5    13626           23       112   27    Male
# ...       ...      ...          ...       ...  ...     ...
# 89192   89193    23996           15        32   25    Male
# 89193   89194    20466           20        47   31    Male
# 89194   89195    13655           16        97   25    Male
# 89195   89196    24840            9        18   35    Male
# 89196   89197    27183           25       150   13    Male
#
#                  profession  followers  views  engagement_score
# 0                   Student        180   1000              4.33
# 1                   Student        330    714              1.79
# ...

# %%
print(traindf.columns.values)
# Out:
# ['row_id' 'user_id' 'category_id' 'video_id' 'age' 'gender' 'profession'
#  'followers' 'views' 'engagement_score']

# %%
traindf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89197 entries, 0 to 89196
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   row_id            89197 non-null  int64
#  1   user_id           89197 non-null  int64
#  2   category_id       89197 non-null  int64
#  3   video_id          89197 non-null  int64
#  4   age               89197 non-null  int64
#  5   gender            89197 non-null  object
#  6   profession        89197 non-null  object
#  7   followers         89197 non-null  int64
#  8   views             89197 non-null  int64
#  9   engagement_score  89197 non-null  float64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 6.8+ MB

# %%
traindf.describe()
# Out:
#              row_id       user_id   category_id      video_id           age  \
# count  89197.000000  89197.000000  89197.000000  89197.000000  89197.000000
# mean   44599.000000  13881.909806     18.323733     77.715383     24.848616
# std    25749.100318   8005.582771     11.675154     48.469656      8.955535
# min        1.000000      1.000000      1.000000      1.000000     10.000000
# 25%    22300.000000   6945.000000      8.000000     34.000000     18.000000
# 50%    44599.000000  13892.000000     16.000000     76.000000     23.000000
# 75%    66898.000000  20819.000000     26.000000    120.000000     32.000000
# max    89197.000000  27734.000000     47.000000    175.000000     68.000000
#
#           followers         views  engagement_score
# count  89197.000000  89197.000000      89197.000000
# mean     252.460172    502.980268          3.487797
# std       46.094468    268.569482          0.863498
# min      160.000000     30.000000          0.000000
# ...

# %%
traindf["category_id"].unique()
# Out:
# array([37, 32, 12, 23, 25,  7,  8,  3,  5, 28, 20, 36, 24, 30, 31,  4,  1,
#        21, 10, 16, 11, 19, 39, 15, 43, 26, 34, 13, 42, 18, 44, 45, 29, 27,
#         9, 17, 40, 14, 38,  6, 35, 41, 46, 22, 33,  2, 47], dtype=int64)

# %%
traindf["video_id"].unique()
# Out:
# array([128, 132,  24, 112, 139,  14, 100,   4, 161,  88,  75,  72,  48,
#        107, 103,  60,  74,  83,  87,  16, 151,  99,  15, 102, 129, 119,
#         13,  51,  38,  35,  22,  76,  45, 116, 109, 146,   1,  67,  32,
#         53, 148, 140,  63, 115, 108, 113,  92,  33, 117, 114,  50,  17,
#          6, 120,  49,  20, 136,  86,  58, 165,  59,  97,  46,  62, 104,
#         26,  71,  29, 123, 167, 163, 125, 145,  81,  65, 162,  18,  77,
#         36,  25,   9, 124,  98,  31,  94,  10,  95, 156,  68,  23, 135,
#        105, 133, 111,   8,  37,  34,  11, 168,  41, 142, 157, 138, 149,
#         96, 150,  30, 134,  42,  28,  66,  56, 143, 106,  27, 141,  40,
#         82,  64,   7, 174, 101, 121, 126,  12, 158, 144, 131, 147, 137,
#         61, 164,  84, 155, 172, 171,  44, 122,  43,  19,  47, 110,  69,
#        173, 130,   5, 127,  39,  52,  79, 152,   2, 170,  89,  70, 153,
#        160,  91,  93,  90, 154,  80, 159, 169,  54,   3,  55,  21,  78,
# ...

# %%
traindf["video_id"].nunique()
# Out:
# 175

# %%
test["video_id"].unique()
# Out:
# array([ 42, 115, 110, 137,  96, 134, 109, 123,  44,  99, 140, 125,   9,
#        157,  19,   6,   7,  33,  29, 104, 100,  40,  28,  15,  14, 120,
#         39,   1, 121,  61, 158,  17,  97,  25,  88,  95, 114, 113,  10,
#         87, 150,  85,  56, 122, 151, 145, 162,  80,  21,  77,  62,  64,
#         13, 132,  22,  91,  41,  46,  82, 160, 101, 169,  30,  98, 105,
#         90, 152, 163,  45, 153, 138, 144, 139,  94,  66,   8,  16,  18,
#         67,  74,  24,  27,  26, 129,  81, 133, 155,  69,  23,  35,   2,
#        168,  70,  34, 143, 156,  20,  71,  59,  86, 146,  73, 161,  55,
#         32,  68, 136, 172,  92, 119, 118,  89, 173,  57,  58,  43,  79,
#        154,  72, 135, 159, 170,  78, 142,  54, 171, 174, 166], dtype=int64)

# %%
traindf["profession"].unique()
# Out:
# array(['Student', 'Working Professional', 'Other'], dtype=object)

# %%
import seaborn as sns

# %%
sns.pairplot(data=traindf)

# %%
sns.displot(x="age",data=traindf,kde=True)

# %%
sns.displot(x="followers",data=traindf,kde=True)

# %%
sns.displot(x="engagement_score",data=traindf,kde=True)

# %%
sns.boxplot(x="followers",data=traindf)
# Out:
# <AxesSubplot:xlabel='followers'>

# %%
sns.boxplot(x="views",data=traindf)
# Out:
# <AxesSubplot:xlabel='views'>

# %%
sns.boxplot(x="engagement_score",data=traindf)
# Out:
# <AxesSubplot:xlabel='engagement_score'>

# %%
sns.boxplot(x="age",data=traindf)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
traindf.corr()
# Out:
#                     row_id   user_id  category_id  video_id       age  \
# row_id            1.000000 -0.006953     0.002833  0.000891 -0.005199
# user_id          -0.006953  1.000000     0.002139  0.005232 -0.000036
# category_id       0.002833  0.002139     1.000000  0.556550 -0.003152
# video_id          0.000891  0.005232     0.556550  1.000000 -0.005615
# age              -0.005199 -0.000036    -0.003152 -0.005615  1.000000
# followers        -0.001374 -0.002026     0.056432  0.098778  0.004623
# views            -0.001815 -0.001843     0.079321 -0.029448  0.011042
# engagement_score -0.003368 -0.002900    -0.094288 -0.030552 -0.232626
#
#                   followers     views  engagement_score
# row_id            -0.001374 -0.001815         -0.003368
# user_id           -0.002026 -0.001843         -0.002900
# category_id        0.056432  0.079321         -0.094288
# video_id           0.098778 -0.029448         -0.030552
# ...

# %% [markdown]
# outlier play

# %%
traindf
# Out:
#        row_id  user_id  category_id  video_id  age  gender  \
# 0           1    19990           37       128   24    Male
# 1           2     5304           32       132   14  Female
# 2           3     1840           12        24   19    Male
# 3           4    12597           23       112   19    Male
# 4           5    13626           23       112   27    Male
# ...       ...      ...          ...       ...  ...     ...
# 89192   89193    23996           15        32   25    Male
# 89193   89194    20466           20        47   31    Male
# 89194   89195    13655           16        97   25    Male
# 89195   89196    24840            9        18   35    Male
# 89196   89197    27183           25       150   13    Male
#
#                  profession  followers  views  engagement_score
# 0                   Student        180   1000              4.33
# 1                   Student        330    714              1.79
# ...

# %% [markdown]
# # Model Building

# %%
traindf['user_id'].nunique()
# Out:
# 27734

# %%
import category_encoders as ce
encoder=ce.TargetEncoder(cols='profession')
enc=encoder.fit(traindf['profession'],traindf['engagement_score'])
traindf["profession"]=encoder.fit_transform(traindf['profession'],traindf['engagement_score'])
test['profession']=enc.transform(test['profession'])
# Out:
# C:\Users\1411t\anaconda3\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# C:\Users\1411t\anaconda3\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
encoder=ce.TargetEncoder(cols='video_id')
enc=encoder.fit(traindf['video_id'],traindf['engagement_score'])
traindf["video_id"]=encoder.fit_transform(traindf['video_id'],traindf['engagement_score'])
test['video_id']=enc.transform(test['video_id'])
# Out:
# C:\Users\1411t\anaconda3\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# C:\Users\1411t\anaconda3\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
encoder=ce.TargetEncoder(cols='category_id')
enc=encoder.fit(traindf['category_id'],traindf['engagement_score'])
traindf["category_id"]=encoder.fit_transform(traindf['category_id'],traindf['engagement_score'])
test['category_id']=enc.transform(test['category_id'])
# Out:
# C:\Users\1411t\anaconda3\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# C:\Users\1411t\anaconda3\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
encoder=ce.TargetEncoder(cols='user_id')
enc=encoder.fit(traindf['user_id'],traindf['engagement_score'])
traindf["user_id"]=encoder.fit_transform(traindf['user_id'],traindf['engagement_score'])
test['user_id']=enc.transform(test['user_id'])
# Out:
# C:\Users\1411t\anaconda3\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# C:\Users\1411t\anaconda3\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
traindf.corr()
# Out:
#                     row_id   user_id  category_id  video_id       age  \
# row_id            1.000000 -0.000752     0.003543  0.001913 -0.005199
# user_id          -0.000752  1.000000     0.188832  0.191817 -0.292025
# category_id       0.003543  0.188832     1.000000  0.926330  0.004869
# video_id          0.001913  0.191817     0.926330  1.000000  0.003476
# age              -0.005199 -0.292025     0.004869  0.003476  1.000000
# profession        0.004594  0.382218    -0.005414 -0.004457 -0.760905
# followers        -0.001374 -0.016304     0.002949  0.005679  0.004623
# views            -0.001815 -0.037581    -0.292125 -0.268108  0.011042
# engagement_score -0.003368  0.801062     0.289874  0.313019 -0.232626
#
#                   profession  followers     views  engagement_score
# row_id              0.004594  -0.001374 -0.001815         -0.003368
# user_id             0.382218  -0.016304 -0.037581          0.801062
# ...

# %%
# Import label encoder
# from sklearn import preprocessing
# label_encoder = preprocessing.LabelEncoder()
# traindf['gender']= label_encoder.fit_transform(traindf['gender'])
# test['gender']= label_encoder.fit_transform(test['gender'])
traindf= pd.get_dummies(traindf, columns = [ 'gender'])
test= pd.get_dummies(test, columns = [ 'gender'])

# %%
X=traindf.drop(columns=['engagement_score','row_id','age'])

y=traindf['engagement_score']

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.38)

# %%
# test=test["user_id"]
test=test.drop(columns=['row_id','age'])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)
test=sc.transform(test)

# from sklearn.preprocessing import MinMaxScaler
# mc=MinMaxScaler()
# X_train=mc.fit_transform(X_train)
# X_test=mc.transform(X_test)
# test=mc.transform(test)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Embedding, Flatten, LeakyReLU, BatchNormalization, Dropout
from keras.activations import relu, sigmoid
from keras.models import Sequential
from keras.layers import Dense, Activation, Embedding, Flatten, LeakyReLU, BatchNormalization, Dropout
from keras.activations import relu, sigmoid
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV
from keras.regularizers import l2
from keras.regularizers import l1
from keras.regularizers import l1_l2

# %%
# def create_model(layers, activation):
#     model = Sequential()
#     for i, nodes in enumerate(layers):
#         if i==0:
#             model.add(Dense(nodes,input_dim=X_train.shape[1]))
#             model.add(Activation(activation))
#         else:
#             model.add(Dense(nodes))
#             model.add(Activation(activation))
#     model.add(Dense(1)) 
    
#     model.compile(optimizer='adam', loss='mean_squared_error',metrics=['mean_absolute_error'])
#     return model
    
# model = KerasRegressor(build_fn=create_model)

# %%
# layers = [[25], [36, 18], [60,30,15],[120,60,30,15]]
# activations = ['linear', 'relu','sigmoid']
# param_grid = dict(layers=layers, activation=activations, batch_size = [128, 256,560], epochs=[10,25])
# grid = GridSearchCV(estimator=model, param_grid=param_grid)
# grid_result = grid.fit(X_train, y_train)
# [grid_result.best_score_,grid_result.best_params_]

# %%
regressor = Sequential()


regressor.add(Dense(units=300, kernel_regularizer="l1", bias_regularizer='l1', kernel_initializer = 'uniform',activation='relu',input_dim =X_train.shape[1]))
regressor.add(BatchNormalization())
regressor.add(Dense(units=150,kernel_regularizer="l1", bias_regularizer='l1',kernel_initializer="uniform",activation='relu'))
regressor.add(BatchNormalization())
regressor.add(Dense(units=75,kernel_regularizer="l1", bias_regularizer='l1',kernel_initializer="uniform",activation='relu'))
regressor.add(BatchNormalization())

regressor.add(Dense(units=50, kernel_regularizer='l1', bias_regularizer='l1',kernel_initializer = 'uniform', activation = 'relu'))
regressor.add(BatchNormalization())
regressor.add(Dense(units=25, kernel_regularizer='l1', bias_regularizer='l1', kernel_initializer = 'uniform', activation = 'relu'))
regressor.add(BatchNormalization())
regressor.add(Dense(units=15, kernel_regularizer='l1', bias_regularizer='l1', kernel_initializer = 'uniform', activation = 'relu'))
regressor.add(BatchNormalization())
regressor.add(Dense(units=8, kernel_regularizer='l1', bias_regularizer='l1',kernel_initializer = 'uniform', activation = 'relu'))
regressor.add(BatchNormalization())
regressor.add(Dense(units=4, kernel_regularizer='l1', bias_regularizer='l1', kernel_initializer = 'uniform', activation = 'relu'))
regressor.add(BatchNormalization())
regressor.add(Dense(units=2, kernel_regularizer='l1', bias_regularizer='l1', kernel_initializer = 'uniform', activation = 'relu'))
regressor.add(BatchNormalization())
regressor.add(Dense(units=1, kernel_regularizer='l1', bias_regularizer='l1',kernel_initializer = 'uniform', activation = 'linear'))
regressor.add(BatchNormalization())
regressor.compile(optimizer = 'Adamax', loss = 'mean_squared_error', metrics = ['mse', 'mae', 'mape'])
model_history=regressor.fit(X_train, y_train,validation_split=0.30, batch_size = 1500, epochs=300)
# Out:
# Epoch 1/300
# 26/26 [==============================] - 9s 75ms/step - loss: 24.8581 - mse: 12.4384 - mae: 3.4751 - mape: 3540786.0000 - val_loss: 21.7436 - val_mse: 12.7272 - val_mae: 3.4625 - val_mape: 51330.2031
# Epoch 2/300
# 26/26 [==============================] - 1s 26ms/step - loss: 19.0244 - mse: 12.1635 - mae: 3.4493 - mape: 4476241.5000 - val_loss: 17.4679 - val_mse: 12.5479 - val_mae: 3.4366 - val_mape: 104591.3672
# Epoch 3/300
# 26/26 [==============================] - 1s 28ms/step - loss: 15.6798 - mse: 11.9760 - mae: 3.4234 - mape: 4296312.0000 - val_loss: 14.9931 - val_mse: 12.3697 - val_mae: 3.4107 - val_mape: 157905.7656
# Epoch 4/300
# 26/26 [==============================] - 1s 27ms/step - loss: 13.7806 - mse: 11.7950 - mae: 3.3976 - mape: 4446067.0000 - val_loss: 13.6266 - val_mse: 12.1947 - val_mae: 3.3851 - val_mape: 210689.6094
# Epoch 5/300
# ...

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_pred,y_test,squared=False)
# Out:
# 0.4948530109061088

# %%
ytesterfunc=regressor.predict(test)

# %%
from sklearn.metrics import r2_score
r2_score(y_pred, y_test)
# Out:
# 0.5050274275540374

# %%
# ytesterfunc.shape

# %%
# from sklearn.linear_model import LinearRegression, LogisticRegression, Ridge
# from sklearn.tree import DecisionTreeRegressor
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.model_selection import ShuffleSplit,cross_val_score,KFold,StratifiedKFold,LeavePOut,LeaveOneOut
# from sklearn.model_selection import GridSearchCV

# def find_best_model_using_gridsearchcv(X_train,y_train):
#     algos = {
#         'linear_regression' : {
#             'model': LinearRegression(),
#             'params': {
#                 'fit_intercept': [True, False],
#                 'normalize': [True, False],

#             }
#         },
#         'KNeighborsRegressor': {
#             'model': KNeighborsRegressor(),
#             'params': {
#                 'n_neighbors' : [5,7,10]
#             }
#         },
#         'LogisticRegression': {
#             'model': LogisticRegression(),
#             'params': {

#             }
#         },
#         'decision_tree': {
#             'model': DecisionTreeRegressor(),
#             'params': {
#                 'criterion' : ['mse','friedman_mse'],
#                 'splitter': ['best','random']
#             }
#         }
#     }
#     scores = []
#     cv=KFold(n_splits=5)

#     for algo_name, config in algos.items():
#         gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
#         gs.fit(X,y)
#         scores.append({
#             'model': algo_name,
#             'best_score': gs.best_score_,
#             'best_params': gs.best_params_
#         })

#     return pd.DataFrame(scores,columns=['model','best_score','best_params'])
# find_best_model_using_gridsearchcv(X_train,y_test)

# %%
# from sklearn import preprocessing, svm
# from sklearn.model_selection import train_test_split
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.svm import SVR
# from sklearn.neighbors import KNeighborsRegressor
# import lightgbm as lgb
# from sklearn.ensemble import AdaBoostRegressor
# from sklearn.ensemble import BaggingRegressor
# from sklearn.linear_model import HuberRegressor,BayesianRidge
# # regr = lgb.LGBMRegressor(learning_rate=0.116)
# # regr.fit(X_train,y_train,eval_set=[(X_test,y_test),(X_train,y_train)],eval_metric='l2')
# regr = HuberRegressor(epsilon=2,max_iter=4000,alpha=0.01,warm_start=True)
# # regr = BaggingRegressor(base_estimator=HuberRegressor(),n_estimators=100)
# regr.fit(X_train, y_train)
# y_pred = regr.predict(X_test)
# regr.score(X_test, y_test)
# Out:
# 0.6619598749993092

# %% [markdown]
# # Submission File
# Creation

# %%
df = pd.DataFrame(ytesterfunc, columns = ['engagement_score'])

# %%
test_df=pd.read_csv("test.csv")
submission = pd.DataFrame({
        "row_id": test_df["row_id"],
        "engagement_score": df["engagement_score"]
    })

# %%
submission.to_csv("submission1.csv",index=False)
